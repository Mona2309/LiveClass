# %%
import pandas as pd

# %%
pd.read_csv('sample.csv')
# Out:
#         name  lastname            emailid  age    address     pin
# 0         rah     efer     fewt@gamil.com   30  bangalore   32567
# 1    hisjoffe  ewegwht   fdffet@gamil.com   45        hyd  647485
# 2      dhsiff    esffg   fdfsst@gamil.com   67        kol  546578
# 3   dijfoefel    hyjyg  dfdsfgt@gamil.com   88       pune   54567
# 4  jfejofemfl     tjyi    safst@gamil.com   33     mumbai  567789

# %%
pd.read_csv('taxonomy.csv')
# Out:
#     Taxonomy_id                          name parent_id           parent_name  \
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
#      Unnamed: 4
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 285         NaN
# 286         NaN
# 287         NaN
# 288         NaN
# 289         NaN
#
# [290 rows x 5 columns]

# %%
df = pd.read_csv('taxonomy.csv')

# %%
df
# Out:
#     Taxonomy_id                          name parent_id           parent_name  \
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
#      Unnamed: 4
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 285         NaN
# 286         NaN
# 287         NaN
# 288         NaN
# 289         NaN
#
# [290 rows x 5 columns]

# %%
pandas.core.frame.DataFrame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\MONALI~1.DHA\AppData\Local\Temp/ipykernel_30048/541309218.py in <module>
# ----> 1 pandas.core.frame.DataFrame
#
# NameError: name 'pandas' is not defined

# %%
df.columns
# Out:
# Index(['Taxonomy_id', 'name', 'parent_id', 'parent_name', 'Unnamed: 4'], dtype='object')

# %%
df.dtypes
# Out:
# Taxonomy_id     object
# name            object
# parent_id       object
# parent_name     object
# Unnamed: 4     float64
# dtype: object

# %%
a = df['parent_id']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
type(df[['Taxonomy_id']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(a)
# Out:
# type

# %%
df = pd.ExcelFile('sampledatafoodsales.xlsx')

# %%
df1 = pd.read_excel('sampledatafoodsales.xlsx',sheet_name= 'FoodSales')

# %%
df.sheet_names
# Out:
# ['Instructions', 'FoodSales', 'MyLinks']

# %%
for i in

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]
